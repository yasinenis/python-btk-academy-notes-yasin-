# %% [markdown]
# # Request Modülü

# %% [markdown]
# * bilgisayara python kurulumu ile gelmeyen bir paket
# * internet üzerinden kendimiz yüklememiz gerekiyor.(PyPi.org)
#
#         pip --version       :
#         bunu terminale yazarak pip paket yöneticisinin versiyonuna baktık
#
#         pip install request :
#         terminale yazarsak request modülünü yükler
#
#      NOT: hangi modül için terminale ne yazacağımız PyPi.org da var
#
#         pip list            :  o anda hangi modüller yüklü liste halinde verir

# %% [markdown]
# ## Ne işimize yarar?
# * herhangi bir internet sitesinin kaynak (html) kodlarına ulaşabiliyoruz.
#
# * bir sitedeki json bilgileri almaya çalışalım ⇲
#
#         get()           : içine yazılan adresteki bilgiyi alır
#
#         .text           : alınmış adresteki bilgiyi text e çevirir

# %%
import requests

result = requests.get("https://jsonplaceholder.typicode.com/todos")
print(result)   # site bize 200 kodunu gönderdi bunun anlamı her şey yolunda

result = result.text    # adres üzerinden gelen tüm json bilgi yazdırıldı
print(result)

# gelen bilginin tipine bakalım
print(type(result)) # str dedi

# gelen bilgi string ise içinden herhangi bir bilgiyi alabilir miyim?
'''
print(result[0]["Title"])
'''
# hata verdi çünkü string bir ifadede dict tipiymiş gibi cımbızlayamayız

# ne yapıcaz?
# json stringi dict e dönüştürücez

# %% [markdown]
# * json kullanarak stringi dict e dönüştürelim

# %%
import requests
import json # json string den dict e dönüştürmek için

result = requests.get("https://jsonplaceholder.typicode.com/todos")

print("🐛dict halde sitedeki tüm bilgiler🐛".center(50," "))
result = json.loads(result.text)    # düzenlendi
print(result)   # sitedeki tüm bilgiyi busefer json stringinden dict e çevirilmiş halde getirdik buraya

# artık içinden cımbızla bilgi alabilriz (dict halde)
print("🐛içinden teker teker ulaştıklarımız🐛".center(50," "))
print(result[0])
print(result[0]["title"])
# Out:
#         🐛dict halde sitedeki tüm bilgiler🐛
# ...

# %% [markdown]
# * for kullanarak gelen bilgileri satır satır yazılsın düzenli

# %%
import requests
import json 

result = requests.get("https://jsonplaceholder.typicode.com/todos")

print("🐛dict halde sitedeki tüm bilgiler🐛".center(50," "))
result = json.loads(result.text)   
print(result)   

# ------yukarısı değişmedi--------

# bu sefer daha düzenli bir şekilde alalım

for i in result:
    print(i)
# Out:
#         🐛dict halde sitedeki tüm bilgiler🐛
# ...

# %% [markdown]
# * bu sefer sadece

# %%
import requests
import json 

result = requests.get("https://jsonplaceholder.typicode.com/todos")

print("🐛dict halde sitedeki tüm bilgiler🐛".center(50," "))
result = json.loads(result.text)   
print(result)   

# ------yukarısı değişmedi--------

# peki satır satır gelen bilgiler üzerinden herhangi bir bilgiye ulaşmak istersek?
for i in result:
    print(i["title"])

    # bu sefer sadece title bilgisini satır satır yazdı.
# Out:
#         🐛dict halde sitedeki tüm bilgiler🐛
# ...

# %% [markdown]
# * peki bir filtreleme yapmak istersem ?

# %%
import requests
import json 

result = requests.get("https://jsonplaceholder.typicode.com/todos")

print("🐛dict halde sitedeki tüm bilgiler🐛".center(80,"-"))
result = json.loads(result.text)   
print(result)

# ------yukarısı değişmedi--------
print("🐛sadece userId'si 1 olanların title ını🐛".center(80,"-"))

for i in result:
    if i["userId"] == 1: # sadece userId'si 1 olanların title ını yaz demek istedik
        print(i["title"])
# Out:
# -----------------------🐛dict halde sitedeki tüm bilgiler🐛-----------------------
# ...
