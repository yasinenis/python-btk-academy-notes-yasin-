# %% [markdown]
# # Demo YouTube İstatistik Verilerinin Analizi

# %% [markdown]
#         1- İlk 10 kaydı getiriniz.

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

print(df.head(10))
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
# 5  AumaWl0TNBo      17.14.11
# 6  2Vv-BfVoq4g      17.14.11
# 7  -N5eucPMTTc      17.14.11
# 8  LMCuKltaY3M      17.14.11
# 9  9t9u_yPEidY      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
# 5                       How My Relationship Started!
# 6        Ed Sheeran - Perfect (Official Music Video)
# 7                      CHRISTMAS HAS GONE TO MY HEAD
# 8   Elbow - Golden Slumbers (John Lewis Advert 2017)
# 9  Jennifer Lopez - Amor, Amor, Amor (Official Vi...
#
# ...

# %% [markdown]
#         2- İkinci 5 kaydı getiriniz.

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

result = df[5:10]
print(result)
# Out:
#       video_id trending_date  \
# 5  AumaWl0TNBo      17.14.11
# 6  2Vv-BfVoq4g      17.14.11
# 7  -N5eucPMTTc      17.14.11
# 8  LMCuKltaY3M      17.14.11
# 9  9t9u_yPEidY      17.14.11
#
#                                                title       channel_title  \
# 5                       How My Relationship Started!  PointlessBlogVlogs
# 6        Ed Sheeran - Perfect (Official Music Video)          Ed Sheeran
# 7                      CHRISTMAS HAS GONE TO MY HEAD          MoreZoella
# 8   Elbow - Golden Slumbers (John Lewis Advert 2017)           ElbowVEVO
# 9  Jennifer Lopez - Amor, Amor, Amor (Official Vi...   JenniferLopezVEVO
#
#    category_id              publish_time  \
# 5           24  2017-11-11T17:00:00.000Z
# 6           10  2017-11-09T11:04:14.000Z
# 7           22  2017-11-10T19:19:43.000Z
# 8           10  2017-11-10T08:00:01.000Z
# 9           10  2017-11-10T15:00:00.000Z
#
#                                                 tags     views    likes  \
# ...

# %% [markdown]
#         3- Dataset' de bulunan kolon isimleri ve sayısını bulunuz.

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

# kolon isimleri
result = df.columns
print(result)

# kolon sayısı
result = len(df.columns)
print(result)
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')
# 16

# %% [markdown]
#         4- Aşağıda bulunan bazı kolonları silin ve kalan kolonları listeleyiniz.
#
#         (thumbnail_link,comments_disabled,ratings_disabled,video_error_or_removed,description)

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

df = df.drop(["thumbnail_link","comments_disabled","ratings_disabled","video_error_or_removed","description"], axis= 1)
result = df
print(result)
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# 2      n1WpP7iowLc      17.14.11
# 3      PUTEiSjKwJU      17.14.11
# 4      rHwDegptbI4      17.14.11
# ...            ...           ...
# 38911  l884wKofd54      18.14.06
# 38912  IP8k2xkhOdI      18.14.06
# 38913  Il-an3K9pjg      18.14.06
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# 2             Eminem - Walk On Water (Audio) ft. Beyoncé
# 3      Goals from Salford City vs Class of 92 and Fri...
# 4      Dashcam captures truck's near miss with child ...
# ...                                                  ...
# 38911  Enrique Iglesias - MOVE TO MIAMI (Official Vid...
# 38912  Jacob Sartorius - Up With It (Official Music V...
# ...

# %% [markdown]
#         5- Beğenme (like) ve beğenmeme (dislike) sayılarının ortalamasını bulunuz.

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

# likes ortalama
result = df["likes"].mean()
print(result)

# dislike ortalama
result = df["dislikes"].mean()
print(result)
# Out:
# 134519.55349984582
# 7612.559975331483

# %% [markdown]
#         6- ilk 50 videonun like ve dislike kolonlarını getiriniz.

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

result = df[["likes","dislikes"]].head(50)
print(result)
# Out:
#       likes  dislikes
# 0     55681     10247
# 1     25561      2294
# 2    787420     43420
# 3       193        12
# 4        30         2
# 5     52708      1431
# 6   1634124     21082
# 7     57309       749
# 8      2163       147
# 9    190084     15015
# 10     9591       266
# 11     1746       125
# 12    37986       816
# 13     8133      2693
# 14    98804     11682
# 15    12553      2146
# 16    22326       833
# 17   286269      4083
# 18   202676      3394
# 19    72593      1830
# 20    10028       248
# 21   263918      1502
# 22   207262      3167
# 23    25115       499
# 24     4577       292
# 25    52829      1524
# 26      629        77
# 27     5029        81
# 28   307435      2573
# 29      399        14
# 30     5364       153
# 31     7999        84
# 32    84426      1130
# 33     1881       182
# 34      240        16
# 35   126078     10294
# 36       33         6
# 37     1267        38
# 38     4604        46
# 39    53572       168
# ...

# %% [markdown]
#         7- En çok görüntülenen video hangisidir ?

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

result = df[df["views"].max() == df["views"]].iloc[0]["title"]
print(result)
# Out:
# Nicky Jam x J. Balvin - X (EQUIS) | Video Oficial | Prod. Afro Bros & Jeon

# %% [markdown]
#         8- En düşük görüntülenen video hangisidir?

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

result = df[df["views"].min() == df["views"]].iloc[0]["title"]
print(result)
# Out:
# Mountain Bikers Worried About Military Land Being Fenced Off

# %% [markdown]
#         9- En fazla görüntülenen ilk 10 video hangisidir ?

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

result = df.sort_values("views" , ascending= False)[["title","views"]].head(10) # ascending false : azalan şekilde sıralansın demek
print(result)
# Out:
#                                                    title      views
# 28412  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  424538912
# 28212  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  413586699
# 28008  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  402650804
# 27811  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  392036878
# 27615  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  382401497
# 27424  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  372399338
# 27241  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  362111555
# 27052  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  349987176
# 26861  Nicky Jam x J. Balvin - X (EQUIS) | Video Ofic...  339629489
# 34460  Te Bote Remix - Casper, Nio García, Darell, Ni...  337621571

# %% [markdown]
#         10- Kategoriye göre beğeni ortalamalarını sıralı şekilde getiriniz.

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

result = df.groupby("category_id").mean().sort_values("likes")["likes"]
print(result)
# Out:
# category_id
# 19      9674.447917
# 2      24608.506944
# 25     25021.685714
# 26     26639.183091
# 15     28629.913858
# 27     38440.687090
# 20     39220.127517
# 17     39270.313057
# 43     41836.900000
# 22     46273.495899
# 1      57205.523089
# 28     61531.127413
# 23     78431.168490
# 24     81572.362012
# 29    271695.733333
# 10    272138.508943
# Name: likes, dtype: float64
# C:\Users\Yasin\AppData\Local\Temp\ipykernel_4408\633530050.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   result = df.groupby("category_id").mean().sort_values("likes")["likes"]

# %% [markdown]
#         11- Kategoriye göre yorum sayılarını yukarıdan aşağıya sıralayınız.

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

result = df.groupby("category_id").sum().sort_values("comment_count" , ascending= False)["comment_count"]
print(result)
# Out:
# category_id
# 10    293013140
# 24    116897440
# 22     18713149
# 23     16718816
# 1      15590011
# 17     10056226
# 25      9386604
# 29      7672790
# 26      7356296
# 20      6166994
# 28      4029065
# 27      1636903
# 15      1404698
# 2        505085
# 19       118177
# 43        80957
# Name: comment_count, dtype: int64
# C:\Users\Yasin\AppData\Local\Temp\ipykernel_4408\2672038588.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   result = df.groupby("category_id").sum().sort_values("comment_count" , ascending= False)["comment_count"]

# %% [markdown]
#         12- Her kategoride kaç video vardır ?

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

result = df["category_id"].value_counts()
print(result)
# Out:
# 10    13754
# 24     9124
# 22     2926
# 1      2577
# 26     1928
# 17     1907
# 23     1828
# 20     1788
# 25     1225
# 15      534
# 28      518
# 27      457
# 2       144
# 19       96
# 29       90
# 43       20
# Name: category_id, dtype: int64

# %% [markdown]
#         13- Her videonun title uzunluğu bilgisini yeni bir kolonda gösteriniz.

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

df["title_len"] = df["title"].apply(len)

result = df
print(result.head(3))
# Out:
#       video_id trending_date                                          title  \
# 0  Jw1Y-zhQURU      17.14.11  John Lewis Christmas Ad 2017 - #MozTheMonster
# 1  3s1rvMFUweQ      17.14.11      Taylor Swift: …Ready for It? (Live) - SNL
# 2  n1WpP7iowLc      17.14.11     Eminem - Walk On Water (Audio) ft. Beyoncé
#
#          channel_title  category_id              publish_time  \
# 0           John Lewis           26  2017-11-10T07:38:29.000Z
# 1  Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2           EminemVEVO           10  2017-11-10T17:00:03.000Z
#
#                                                 tags     views   likes  \
# 0  christmas|"john lewis christmas"|"john lewis"|...   7224515   55681
# 1  SNL|"Saturday Night Live"|"SNL Season 43"|"Epi...   1053632   25561
# 2  Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787420
#
#    dislikes  comment_count                                  thumbnail_link  \
# ...

# %% [markdown]
#         14- Her video için kullanılan tag sayısını yeni kolonda gösteriniz.

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

# tagları split ile | dan ayrıyoruz liste haline gelen yeni tagları da len ile sayısını hesaplamış oluyoruz
df["tag_count"] = df["tags"].apply(lambda x: len(x.split('|')))

result = df
print(result.head(1))
# Out:
#       video_id trending_date                                          title  \
# 0  Jw1Y-zhQURU      17.14.11  John Lewis Christmas Ad 2017 - #MozTheMonster
#
#   channel_title  category_id              publish_time  \
# 0    John Lewis           26  2017-11-10T07:38:29.000Z
#
#                                                 tags    views  likes  \
# 0  christmas|"john lewis christmas"|"john lewis"|...  7224515  55681
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     10247           9479  https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
#
#                                          description  tag_count
# 0  Click here to continue the story and make your...          9

# %% [markdown]
# * alternatif olarak

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

# bu sefer lambda ile değil de normal fonksiyon gibi yapalım

def tagCount(tag):
    return len(tag.split('|'))

df["tag_count"] = df["tags"].apply(tagCount)
result = df
print(result.head(1))
# Out:
#       video_id trending_date                                          title  \
# 0  Jw1Y-zhQURU      17.14.11  John Lewis Christmas Ad 2017 - #MozTheMonster
#
#   channel_title  category_id              publish_time  \
# 0    John Lewis           26  2017-11-10T07:38:29.000Z
#
#                                                 tags    views  likes  \
# 0  christmas|"john lewis christmas"|"john lewis"|...  7224515  55681
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0     10247           9479  https://i.ytimg.com/vi/Jw1Y-zhQURU/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
#
#                                          description  tag_count
# 0  Click here to continue the story and make your...          9

# %% [markdown]
#         15- En popüler videoları listeleyiniz.(like/dislike oranına göre)

# %%
import pandas as pd
df = pd.read_csv("youtube-ing.csv")
#--- temel kod

# dataFrame deki her bir videonun like & dislike sayısını bir liste içine alalım.
def likeDislikeOranHesapla(dataset):
    likesList = list(df["likes"])   # list metodu otomatik liste içine aldı
    dislikesList = list(df["dislikes"])

    # bize iki bilgi tuple listesi olarak gelsin
    liste = list(zip(likesList, dislikesList))   # zip metodu tuple listesi yapıyor # birde list ile liste ye de çevirdik
    print(liste)    # liste içinde tuple lar var

    # liste halindeki like dislike oranları hesaplamak istiyoruz
    oranListesi = []
    for like,dislike in liste:
        if (like + dislike) == 0:   # like ve dislike bilgisi 0 ise
            oranListesi.append(0)   # beğenilme oranı 0 olarak oranListesine eklensin
        else:   # diğer durum yani like & dislike bilgisi 0 değilse hesaplanacak oran vardır
            oranListesi.append(like/(like+dislike))
    return oranListesi

# hatta bir kolon ekleyip bu oranları orada gösterelim
df["beğeni_orani"] = likeDislikeOranHesapla(df)

print(df.sort_values("beğeni_orani", ascending= False).head()[["title","likes","dislikes","beğeni_orani"]])
# Out:
# [(55681, 10247), (25561, 2294), (787420, 43420), (193, 12), (30, 2), (52708, 1431), (1634124, 21082), (57309, 749), (2163, 147), (190084, 15015), (9591, 266), (1746, 125), (37986, 816), (8133, 2693), (98804, 11682), (12553, 2146), (22326, 833), (286269, 4083), (202676, 3394), (72593, 1830), (10028, 248), (263918, 1502), (207262, 3167), (25115, 499), (4577, 292), (52829, 1524), (629, 77), (5029, 81), (307435, 2573), (399, 14), (5364, 153), (7999, 84), (84426, 1130), (1881, 182), (240, 16), (126078, 10294), (33, 6), (1267, 38), (4604, 46), (53572, 168), (4935, 177), (19323, 245), (9210, 71), (32648, 6221), (3946, 295), (11107, 212), (22303, 700), (3872, 16), (65854, 2442), (14303, 398), (5376, 202), (7158, 89), (6016, 231), (810895, 16139), (8874, 939), (15247, 385), (915, 12), (1991, 83), (86207, 1775), (91393, 2766), (42, 8), (26917, 1979), (470, 104), (31892, 197), (909, 52), (801, 202), (5723, 55), (1826, 91), (401, 58), (293, 9), (342, 50), (37439, 590), (5039, 101), (5675, 41), (
# ...
