# %% [markdown]
# # Pandas ile Kayıp ve Bozuk Veri Analizi

# %%
import pandas as pd
import numpy as np

# 10 -100 arsı 15 sayıdan oluşan 5 e 3 lük matrix oluşturalım
data = np.random.randint(10,100,15).reshape(5,3)
# dataFrame oluşturalım
df = pd.DataFrame(data, index= ['a', 'c', 'e', 'f', 'h'], columns = ['column1','column2','column3'])
# dataFrame tekrar indexleyelim (aralara 3 index daha ekledik)
df = df.reindex(['a','b','c','d','e','f','g','h'])

result = df
print(result)
# Out:
#    column1  column2  column3
# a     80.0     80.0     76.0
# b      NaN      NaN      NaN
# c     67.0     30.0     12.0
# d      NaN      NaN      NaN
# e     76.0     24.0     37.0
# f     70.0     18.0     90.0
# g      NaN      NaN      NaN
# h     56.0     57.0     24.0

# %% [markdown]
# * devam
# * istemediğimiz kolon & satırları nasıl datasetinin içinden sileceğiz bunu görücez
#
#         drop()

# %%
import pandas as pd
import numpy as np

# 10 -100 arsı 15 sayıdan oluşan 5 e 3 lük matrix oluşturalım
data = np.random.randint(10,100,15).reshape(5,3)
# dataFrame oluşturalım
df = pd.DataFrame(data, index= ['a', 'c', 'e', 'f', 'h'], columns = ['column1','column2','column3'])
# dataFrame tekrar indexleyelim (aralara 3 index daha ekledik)
df = df.reindex(['a','b','c','d','e','f','g','h'])
#---- temel kod

# kolon1 'i silelim drop() kullanarak
result = df.drop("column1", axis= 1)    # axis 0 : yatay axis 1 : dikey demek
print(result)
print("             ◽   ◽   ◽")

# birden fazla kolon silmek istersek..
result = df.drop(["column1","column2"], axis= 1)
print(result)
print("             ◽   ◽   ◽")

# a indexini silmek istersek
result = df.drop('a', axis= 0)  # a indexi yatayda old. için axis = 0
print(result)
# Out:
#    column2  column3
# a     40.0     95.0
# b      NaN      NaN
# c     96.0     14.0
# d      NaN      NaN
# e     74.0     37.0
# f     78.0     60.0
# g      NaN      NaN
# h     46.0     70.0
#              ◽   ◽   ◽
#    column3
# a     95.0
# b      NaN
# c     14.0
# d      NaN
# e     37.0
# f     60.0
# g      NaN
# h     70.0
#              ◽   ◽   ◽
#    column1  column2  column3
# b      NaN      NaN      NaN
# c     76.0     96.0     14.0
# d      NaN      NaN      NaN
# e     84.0     74.0     37.0
# f     43.0     78.0     60.0
# g      NaN      NaN      NaN
# h     66.0     46.0     70.0

# %% [markdown]
# * devam

# %%
import pandas as pd
import numpy as np

# 10 -100 arsı 15 sayıdan oluşan 5 e 3 lük matrix oluşturalım
data = np.random.randint(10,100,15).reshape(5,3)
# dataFrame oluşturalım
df = pd.DataFrame(data, index= ['a', 'c', 'e', 'f', 'h'], columns = ['column1','column2','column3'])
# dataFrame tekrar indexleyelim (aralara 3 index daha ekledik)
df = df.reindex(['a','b','c','d','e','f','g','h'])
#---- temel kod

# birden fazla index silmek istersek
result = df.drop(['a','b','h'], axis= 0)
print(result)
# Out:
#    column1  column2  column3
# c     80.0     80.0     81.0
# d      NaN      NaN      NaN
# e     49.0     97.0     83.0
# f     68.0     63.0     45.0
# g      NaN      NaN      NaN

# %% [markdown]
# * peki null yani NaN olan alanları nasıl tespit edeceğiz?
#
#         isnull()
#         notnull()

# %%
import pandas as pd
import numpy as np

# 10 -100 arsı 15 sayıdan oluşan 5 e 3 lük matrix oluşturalım
data = np.random.randint(10,100,15).reshape(5,3)
# dataFrame oluşturalım
df = pd.DataFrame(data, index= ['a', 'c', 'e', 'f', 'h'], columns = ['column1','column2','column3'])
# dataFrame tekrar indexleyelim (aralara 3 index daha ekledik)
df = df.reindex(['a','b','c','d','e','f','g','h'])
#---- temel kod


# isnull() metodu bize null veya NaN olan alanları True olarak gösterir.
result = df.isnull()
print(result)   # null olanlara True verdi
print("             ◽   ◽   ◽")

# null yani NaN olan alanları değilde olmayan alanları True olarak göstersin dersek.
result = df.notnull()
print(result)   # null olmayanlara True verdi.
print("             ◽   ◽   ◽")

# NaN olan değerlerin toplamı bize gelsin istersek..
result = df.isnull().sum()
print(result)
print("             ◽   ◽   ◽")

# sadece bir kolondaki değerleri saymak istersem..
result = df["column1"].isnull().sum()
print(result)
# Out:
#    column1  column2  column3
# a    False    False    False
# b     True     True     True
# c    False    False    False
# d     True     True     True
# e    False    False    False
# f    False    False    False
# g     True     True     True
# h    False    False    False
#              ◽   ◽   ◽
#    column1  column2  column3
# a     True     True     True
# b    False    False    False
# c     True     True     True
# d    False    False    False
# e     True     True     True
# f     True     True     True
# g    False    False    False
# h     True     True     True
#              ◽   ◽   ◽
# column1    3
# column2    3
# column3    3
# dtype: int64
#              ◽   ◽   ◽
# 3

# %% [markdown]
# * içinde nan değerler olan yeni bir kolon daha ekleyip devam edelim.

# %%
import numpy as np
import pandas as pd

# 10 -100 arsı 15 sayıdan oluşan 5 e 3 lük matrix oluşturalım
data = np.random.randint(10,100,15).reshape(5,3)
# dataFrame oluşturalım
df = pd.DataFrame(data, index= ['a', 'c', 'e', 'f', 'h'], columns = ['column1','column2','column3'])
# dataFrame tekrar indexleyelim (aralara 3 index daha ekledik)
df = df.reindex(['a','b','c','d','e','f','g','h'])
#---- temel kod

# yeni kolon oluşturalım
newColumn = [np.nan,30,np.nan,51,np.nan,30,np.nan,10]  # np.nan (nan değer eklemenin kısa yolu) # 8 satır oldu
# kolonu dataFrame imize ekleyelim 4.kolon olarak
df["column4"] = newColumn
#----- güncel temel kod

print(df)
print("             ◽   ◽   ◽")

# null değerlerine bakalım tekrar
result = df["column1"].isnull()
print(result)   # null alanlar için true gösterdi
print("             ◽   ◽   ◽")


# null olan değerleri görelim (true/false olarak değil)
result = df[df["column1"].isnull()]
print(result)   # null olanları gösterirken aynı satırdaki null olmayanları da gösterdi
print("             ◽   ◽   ◽")


# yukarıdaki gibi null olmayanlar araya karışmasın diye sadece kolon1 i göster diye ekleyelim sonuna
result = df[df["column1"].isnull()]["column1"]
print(result)
# Out:
#    column1  column2  column3  column4
# a     57.0     71.0     39.0      NaN
# b      NaN      NaN      NaN     30.0
# c     11.0     54.0     33.0      NaN
# d      NaN      NaN      NaN     51.0
# e     18.0     87.0     96.0      NaN
# f     96.0     74.0     49.0     30.0
# g      NaN      NaN      NaN      NaN
# h     14.0     23.0     25.0     10.0
#              ◽   ◽   ◽
# a    False
# b     True
# c    False
# d     True
# e    False
# f    False
# g     True
# h    False
# Name: column1, dtype: bool
#              ◽   ◽   ◽
#    column1  column2  column3  column4
# b      NaN      NaN      NaN     30.0
# d      NaN      NaN      NaN     51.0
# g      NaN      NaN      NaN      NaN
#              ◽   ◽   ◽
# b   NaN
# d   NaN
# g   NaN
# Name: column1, dtype: float64

# %% [markdown]
# * devam
#
#         dropna()

# %%
import numpy as np
import pandas as pd

# 10 -100 arsı 15 sayıdan oluşan 5 e 3 lük matrix oluşturalım
data = np.random.randint(10,100,15).reshape(5,3)
# dataFrame oluşturalım
df = pd.DataFrame(data, index= ['a', 'c', 'e', 'f', 'h'], columns = ['column1','column2','column3'])
# dataFrame tekrar indexleyelim (aralara 3 index daha ekledik)
df = df.reindex(['a','b','c','d','e','f','g','h'])
# yeni kolon oluşturalım
newColumn = [np.nan,30,np.nan,51,np.nan,30,np.nan,10]  # np.nan (nan değer eklemenin kısa yolu) # 8 satır oldu
# kolonu dataFrame imize ekleyelim 4.kolon olarak
df["column4"] = newColumn
#----- güncel temel kod

# null olmayan halini versin bir öncekinin
result = df[df["column1"].notnull()]["column1"]
print(result)
print("             ◽   ◽   ◽")

# yukarıdakinden column1 filtrelemesini tekrar kaldıralım tüm dataFrame de arasın yine
result = df[df["column1"].notnull()]
print(result)   # column1 de nan olmayan alanları verirken aynı satırlardaki nan olanlar da gösterilmiş oluyor (araya kaynıyor)
print("             ◽   ◽   ◽")

# dropna ile drop dan farklı olarak nan olan değerlerin olduğu satırı & stünu silebiliyoruz 
result = df.dropna() # dropna varsayılan olarak axis = 0 dır o nedenle axis belirtmedik
print(result)
print("             ◽   ◽   ◽")

# yukarıdakinin axis = 1 li halini yapalım
result = df.dropna(axis= 1)
print(result)   # boş değer geldi çünkü nan olmayan hiç bir kolon yok
# Out:
# a    36.0
# c    64.0
# e    25.0
# f    10.0
# h    87.0
# Name: column1, dtype: float64
#              ◽   ◽   ◽
#    column1  column2  column3  column4
# a     36.0     83.0     66.0      NaN
# c     64.0     88.0     46.0      NaN
# e     25.0     85.0     43.0      NaN
# f     10.0     16.0     18.0     30.0
# h     87.0     20.0     45.0     10.0
#              ◽   ◽   ◽
#    column1  column2  column3  column4
# f     10.0     16.0     18.0     30.0
# h     87.0     20.0     45.0     10.0
#              ◽   ◽   ◽
# Empty DataFrame
# Columns: []
# Index: [a, b, c, d, e, f, g, h]

# %% [markdown]
# * devam
#
#         how = ""
#         subset = ""

# %%
import numpy as np
import pandas as pd

# 10 -100 arsı 15 sayıdan oluşan 5 e 3 lük matrix oluşturalım
data = np.random.randint(10,100,15).reshape(5,3)
# dataFrame oluşturalım
df = pd.DataFrame(data, index= ['a', 'c', 'e', 'f', 'h'], columns = ['column1','column2','column3'])
# dataFrame tekrar indexleyelim (aralara 3 index daha ekledik)
df = df.reindex(['a','b','c','d','e','f','g','h'])
# yeni kolon oluşturalım
newColumn = [np.nan,30,np.nan,51,np.nan,30,np.nan,10]  # np.nan (nan değer eklemenin kısa yolu) # 8 satır oldu
# kolonu dataFrame imize ekleyelim 4.kolon olarak
df["column4"] = newColumn
print(df)
#----- güncel temel kod
print("             ◽   ◽   ◽")


# how parametresi var 
# "any"
result = df.dropna(how = "any")    #  any anlamı herhangi bir nan değer bulursa o satır&sütunu siler.
print(result)
print("             ◽   ◽   ◽")

# "all" tüm satır nan ise siler
result = df.dropna(how = "all")
print(result)
print("             ◽   ◽   ◽")

# subset parametresi var
# hangi kolonlar içerisinde yukarıdaki aramaları gerçekleştirebileceğimizi belirtmek için subset
result = df.dropna(subset= ["column1","column2"], how= "all")
print(result)   # iki kolonda da nan değer varsa bu değer getirilmez
print("             ◽   ◽   ◽")

# devam
# Out:
#    column1  column2  column3  column4
# a     73.0     69.0     51.0      NaN
# b      NaN      NaN      NaN     30.0
# c     25.0     85.0     79.0      NaN
# d      NaN      NaN      NaN     51.0
# e     43.0     93.0     17.0      NaN
# f     85.0     38.0     14.0     30.0
# g      NaN      NaN      NaN      NaN
# h     77.0     47.0     23.0     10.0
#              ◽   ◽   ◽
#    column1  column2  column3  column4
# f     85.0     38.0     14.0     30.0
# h     77.0     47.0     23.0     10.0
#              ◽   ◽   ◽
#    column1  column2  column3  column4
# a     73.0     69.0     51.0      NaN
# b      NaN      NaN      NaN     30.0
# c     25.0     85.0     79.0      NaN
# d      NaN      NaN      NaN     51.0
# e     43.0     93.0     17.0      NaN
# f     85.0     38.0     14.0     30.0
# h     77.0     47.0     23.0     10.0
#              ◽   ◽   ◽
#    column1  column2  column3  column4
# a     73.0     69.0     51.0      NaN
# c     25.0     85.0     79.0      NaN
# e     43.0     93.0     17.0      NaN
# f     85.0     38.0     14.0     30.0
# h     77.0     47.0     23.0     10.0
#              ◽   ◽   ◽

# %% [markdown]
# * devam
#
#         thresh = ""

# %%
import numpy as np
import pandas as pd

# 10 -100 arsı 15 sayıdan oluşan 5 e 3 lük matrix oluşturalım
data = np.random.randint(10,100,15).reshape(5,3)
# dataFrame oluşturalım
df = pd.DataFrame(data, index= ['a', 'c', 'e', 'f', 'h'], columns = ['column1','column2','column3'])
# dataFrame tekrar indexleyelim (aralara 3 index daha ekledik)
df = df.reindex(['a','b','c','d','e','f','g','h'])
# yeni kolon oluşturalım
newColumn = [np.nan,30,np.nan,51,np.nan,30,np.nan,10]  # np.nan (nan değer eklemenin kısa yolu) # 8 satır oldu
# kolonu dataFrame imize ekleyelim 4.kolon olarak
df["column4"] = newColumn
print(df)
#----- güncel temel kod
print("             ◽   ◽   ◽")

# yukarıdakinin "any" hali
result = df.dropna(subset= ["column1","column2"], how = "any")
print(result)
print("             ◽   ◽   ◽")

# dropna farklı kullanıma bakalım
# thresh parametresi
# nan değerler haricinde (thresh = 2) iki tane düzgün değer varsa bu kayıtları & satırları silme işime yarıyor demek
result = df.dropna(thresh = 2) 
print(result)   # en az 2 tane düzgün veri olan kayıtları silmez
print("             ◽   ◽   ◽")

# devam
# Out:
#    column1  column2  column3  column4
# a     73.0     21.0     72.0      NaN
# b      NaN      NaN      NaN     30.0
# c     39.0     78.0     55.0      NaN
# d      NaN      NaN      NaN     51.0
# e     23.0     32.0     74.0      NaN
# f     24.0     74.0     92.0     30.0
# g      NaN      NaN      NaN      NaN
# h     97.0     41.0     84.0     10.0
#              ◽   ◽   ◽
#    column1  column2  column3  column4
# a     73.0     21.0     72.0      NaN
# c     39.0     78.0     55.0      NaN
# e     23.0     32.0     74.0      NaN
# f     24.0     74.0     92.0     30.0
# h     97.0     41.0     84.0     10.0
#              ◽   ◽   ◽
#    column1  column2  column3  column4
# a     73.0     21.0     72.0      NaN
# c     39.0     78.0     55.0      NaN
# e     23.0     32.0     74.0      NaN
# f     24.0     74.0     92.0     30.0
# h     97.0     41.0     84.0     10.0
#              ◽   ◽   ◽

# %% [markdown]
# * devam

# %%
import numpy as np
import pandas as pd

# 10 -100 arsı 15 sayıdan oluşan 5 e 3 lük matrix oluşturalım
data = np.random.randint(10,100,15).reshape(5,3)
# dataFrame oluşturalım
df = pd.DataFrame(data, index= ['a', 'c', 'e', 'f', 'h'], columns = ['column1','column2','column3'])
# dataFrame tekrar indexleyelim (aralara 3 index daha ekledik)
df = df.reindex(['a','b','c','d','e','f','g','h'])
# yeni kolon oluşturalım
newColumn = [np.nan,30,np.nan,51,np.nan,30,np.nan,10]  # np.nan (nan değer eklemenin kısa yolu) # 8 satır oldu
# kolonu dataFrame imize ekleyelim 4.kolon olarak
df["column4"] = newColumn
print(df)
#----- güncel temel kod
print("             ◽   ◽   ◽")

# en az 4 yapalım (thresh = 4)
result = df.dropna(thresh = 4) 
print(result)   # sadece iki kayıt varmış
print("             ◽   ◽   ◽")

# en az 3 yapalım
result = df.dropna(thresh = 3) 
print(result)
# Out:
#    column1  column2  column3  column4
# a     13.0     48.0     48.0      NaN
# b      NaN      NaN      NaN     30.0
# c     10.0     32.0     26.0      NaN
# d      NaN      NaN      NaN     51.0
# e     34.0     36.0     24.0      NaN
# f     51.0     57.0     16.0     30.0
# g      NaN      NaN      NaN      NaN
# h     92.0     78.0     56.0     10.0
#              ◽   ◽   ◽
#    column1  column2  column3  column4
# f     51.0     57.0     16.0     30.0
# h     92.0     78.0     56.0     10.0
#              ◽   ◽   ◽
#    column1  column2  column3  column4
# a     13.0     48.0     48.0      NaN
# c     10.0     32.0     26.0      NaN
# e     34.0     36.0     24.0      NaN
# f     51.0     57.0     16.0     30.0
# h     92.0     78.0     56.0     10.0

# %% [markdown]
# NaN olan değerlere farklı bir değer atıyabiliriz
#
#         fillna()
#         value = ""

# %%
import numpy as np
import pandas as pd

# 10 -100 arsı 15 sayıdan oluşan 5 e 3 lük matrix oluşturalım
data = np.random.randint(10,100,15).reshape(5,3)
# dataFrame oluşturalım
df = pd.DataFrame(data, index= ['a', 'c', 'e', 'f', 'h'], columns = ['column1','column2','column3'])
# dataFrame tekrar indexleyelim (aralara 3 index daha ekledik)
df = df.reindex(['a','b','c','d','e','f','g','h'])
# yeni kolon oluşturalım
newColumn = [np.nan,30,np.nan,51,np.nan,30,np.nan,10]  # np.nan (nan değer eklemenin kısa yolu) # 8 satır oldu
# kolonu dataFrame imize ekleyelim 4.kolon olarak
df["column4"] = newColumn
print(df)
#----- güncel temel kod
print("             ◽   ◽   ◽")

# nan olan alanları dolduralım 
# fillna : nan olan alanları doldurur
result = df.fillna(value= 'no input')   # nan olanlara no input desin
print(result)
print("             ◽   ◽   ◽")


# işlem yapacaksak kolaylık olsun diye nan yerlerine 1 yazdırabiliriz
result = df.fillna(value= '1')
print(result)
# Out:
#    column1  column2  column3  column4
# a     11.0     57.0     99.0      NaN
# b      NaN      NaN      NaN     30.0
# c     56.0     12.0     14.0      NaN
# d      NaN      NaN      NaN     51.0
# e     53.0     15.0     24.0      NaN
# f     86.0     12.0     74.0     30.0
# g      NaN      NaN      NaN      NaN
# h     78.0     11.0     39.0     10.0
#              ◽   ◽   ◽
#     column1   column2   column3   column4
# a      11.0      57.0      99.0  no input
# b  no input  no input  no input      30.0
# c      56.0      12.0      14.0  no input
# d  no input  no input  no input      51.0
# e      53.0      15.0      24.0  no input
# f      86.0      12.0      74.0      30.0
# g  no input  no input  no input  no input
# h      78.0      11.0      39.0      10.0
#              ◽   ◽   ◽
#   column1 column2 column3 column4
# a    11.0    57.0    99.0       1
# b       1       1       1    30.0
# c    56.0    12.0    14.0       1
# d       1       1       1    51.0
# e    53.0    15.0    24.0       1
# f    86.0    12.0    74.0    30.0
# g       1       1       1       1
# h    78.0    11.0    39.0    10.0

# %% [markdown]
# * devam

# %%
import pandas as pd

# 10 -100 arsı 15 sayıdan oluşan 5 e 3 lük matrix oluşturalım
data = np.random.randint(10,100,15).reshape(5,3)
# dataFrame oluşturalım
df = pd.DataFrame(data, index= ['a', 'c', 'e', 'f', 'h'], columns = ['column1','column2','column3'])
# dataFrame tekrar indexleyelim (aralara 3 index daha ekledik)
df = df.reindex(['a','b','c','d','e','f','g','h'])
# yeni kolon oluşturalım
newColumn = [np.nan,30,np.nan,51,np.nan,30,np.nan,10]  # np.nan (nan değer eklemenin kısa yolu) # 8 satır oldu
# kolonu dataFrame imize ekleyelim 4.kolon olarak
df["column4"] = newColumn
print(df)
#----- güncel temel kod

# nan yerine listedeki tüm ortalama değerleri yazabiliriz
# bunun için toplam eleman sayısını bulup burdan nan olan alanları çıkarmamız , sonra
# nan harici değerlerin toplamı ve normal olan değerlerin toplamına bölümü

# bu istekle alakalı bir metod oluşturalım ama
# önce bazı bilgileri elde edelim
result = df.sum()   # her kolonun toplam değerlerini getiriyor
print(result)

result = df.sum().sum() # bu sefer gelen kolonların toplamlarını da topladığı için tüm dataframe in toplamını öğrenmiş oluruz.
print(result)

result = df.size # eleman sayısı gelir (nan lar da içinde)
print(result)

result = df.isnull().sum() # null olan alanları hesaplar her kolondaki 
print(result)

result = df.isnull().sum().sum() # hesaplananları da toplar
print(result)

# metodu oluşturalım
def ortalama(df):
    toplam = df.sum().sum()
    adet = df.size - df.isnull().sum().sum()
    return toplam / adet

result = df.fillna(value = ortalama(df))
print(result)   # dataFrame deki nan olan yerleri ortalama ile doldurduk
# Out:
#    column1  column2  column3  column4
# a     72.0     71.0     22.0      NaN
# b      NaN      NaN      NaN     30.0
# c     30.0     61.0     16.0      NaN
# d      NaN      NaN      NaN     51.0
# e     32.0     16.0     97.0      NaN
# f     58.0     11.0     73.0     30.0
# g      NaN      NaN      NaN      NaN
# h     64.0     33.0     76.0     10.0
# column1    256.0
# column2    192.0
# column3    284.0
# column4    121.0
# dtype: float64
# 853.0
# 32
# column1    3
# column2    3
# column3    3
# column4    4
# dtype: int64
# 13
#      column1    column2    column3    column4
# a  72.000000  71.000000  22.000000  44.894737
# b  44.894737  44.894737  44.894737  30.000000
# c  30.000000  61.000000  16.000000  44.894737
# d  44.894737  44.894737  44.894737  51.000000
# e  32.000000  16.000000  97.000000  44.894737
# f  58.000000  11.000000  73.000000  30.000000
# g  44.894737  44.894737  44.894737  44.894737
# h  64.000000  33.000000  76.000000  10.000000
